# %% [markdown]
# # Generative IA

# %% [markdown]
# The idea of this section is to implement a chatbot to answer questions related to the meanings of variables, while been able to add another functions

# %% [markdown]
# # use transformers to access to a model

# %% [markdown]
# # use langchain to create a chain

# %%
from langchain import Message

# %% [markdown]
# # use gcp to create the chain, using it on a odular way
